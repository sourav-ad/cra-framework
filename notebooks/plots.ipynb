# %%
import seaborn as sns
import pandas as pd
import os

# %%
path = "/home/sourav/cra"

# %%
df = pd.read_csv(os.path.join(path, "data/simulated_data_n500.csv"))

# %%
sns.pairplot(df, hue='A', vars=['S3','S4'])

# %%
df.groupby('A')['R'].mean()
# Out:
# A
# 0   -0.012463
# 1    0.268670
# 2    0.845771
# Name: R, dtype: float64
